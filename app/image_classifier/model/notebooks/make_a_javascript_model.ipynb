# %%
import tensorflow as tf
import tensorflow.keras as keras
import tensorflowjs as tfjs
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-9141d422fa50> in <module>
#       1 import tensorflow as tf
#       2 import tensorflow.keras as keras
# ----> 3 import tensorflowjs as tfjs
#       4 import os
#
# ModuleNotFoundError: No module named 'tensorflowjs'

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- -----------
# absl-py                0.9.0
# asgiref                3.2.10
# astroid                2.4.2
# astunparse             1.6.3
# bcrypt                 3.1.7
# cachetools             4.1.1
# certifi                2020.6.20
# cffi                   1.14.0
# chardet                3.0.4
# cryptography           2.9.2
# Django                 3.0
# Fabric3                1.14.post1
# gast                   0.3.3
# google-auth            1.19.1
# google-auth-oauthlib   0.4.1
# google-pasta           0.2.0
# grpcio                 1.30.0
# gunicorn               20.0.0
# h5py                   2.10.0
# idna                   2.10
# isort                  4.3.21
# Keras-Preprocessing    1.1.2
# lazy-object-proxy      1.4.3
# Markdown               3.2.2
# mccabe                 0.6.1
# numpy                  1.18.5
# oauthlib               3.1.0
# opencv-python          4.2.0.34
# opt-einsum             3.2.1
# ...

# %%
# !pip install --upgrade --force-reinstall tensorflowjs
# Out:
# ...
#   Using cached tensorflowjs-2.0.1.post1-py3-none-any.whl (60 kB)
# Processing /home/tornike/.cache/pip/wheels/bd/f3/88/f02d7b8ae8d125c2ab25d91e2c65fea21a17fb9324371f906a/PyInquirer-1.0.3-py3-none-any.whl
# ...
#   Using cached h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
# ...
#   Using cached tensorflow_cpu-2.2.0-cp38-cp38-manylinux2010_x86_64.whl (144.5 MB)
# ...
#   Using cached numpy-1.18.5-cp38-cp38-manylinux1_x86_64.whl (20.6 MB)
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached tensorflow_hub-0.7.0-py2.py3-none-any.whl (89 kB)
# ...
#   Using cached Pygments-2.6.1-py3-none-any.whl (914 kB)
# ...
#   Using cached prompt_toolkit-1.0.14-py3-none-any.whl (248 kB)
# ...
#   Using cached regex-2020.7.14-cp38-cp38-manylinux2010_x86_64.whl (672 kB)
# ...
#   Using cached protobuf-3.12.2-cp38-cp38-manylinux1_x86_64.whl (1.3 MB)
# ...
#   Using cached gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# ...
#   Using cached grpcio-1.30.0-cp38-cp38-manylinux2010_x86_64.whl (3.0 MB)
# ...

# %%
model = keras.models.load_model('../export/0001')

# %%
# !conda list
# Out:
# # packages in environment at /home/tornike/.anaconda3/envs/nailbiter:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# ca-certificates           2020.6.24                     0
# certifi                   2020.6.20                py38_0
# chardet                   3.0.4                    pypi_0    pypi
# idna                      2.10                     pypi_0    pypi
# ld_impl_linux-64          2.33.1               h53a641e_7
# libedit                   3.1.20191231         h7b6447c_0
# libffi                    3.3                  he6710b0_1
# libgcc-ng                 9.1.0                hdf63c60_0
# libstdcxx-ng              9.1.0                hdf63c60_0
# markdown                  3.2.2                    pypi_0    pypi
# ncurses                   6.2                  he6710b0_1
# oauthlib                  3.1.0                    pypi_0    pypi
# ...
